# %%
#crear clase


class TiendaOnline:
#constructor de la clase con los atributos y las listas y diccionarios vacíos de los atributos   
    def __init__(self, nombre):
        self.nombre = nombre
        self.inventario = [] # crear el primer atributo, inventario. 
                            #será una lista de diccionarios con las claves, nombre, precio y cantidad
        self.clientes = {} # atributo clientes, será un diccionario con el id cliente
                            # con las claves nombre y email, 
                            # y una lista con el historial de compras 
        self.ventas = 0.0 

# crear una instancia
mi_tiendaOnline = TiendaOnline("mi_tiendaOnline")

# %%
# métodos

#1.
# #método agregar productos, si ya existe actualiza la cantidad, 
# y si no existe, agrega el producto al inventario

def agregar_producto(self, id_producto, nombre, precio, cantidad):
    # verificar si ya existe 
    for id_producto in self.inventario:
        if id_producto[1] in self.inventario:
        # si existe, actualizar cantidad
            self.inventario[id_producto][1] >= cantidad
        return
    
    #si no existe, agregarlo
    nuevo_producto = {"id": id_producto, "nombre": nombre, float: "precio", int: cantidad}
    self.inventario.append(id_producto)
        
    print(f"el producto con {id_producto} se ha actualizado")

#utilizar los métodos

#método agregar productos

#lista_productos = mi_tiendaOnline.agregar_producto(1,"camisa", 20, 40 )

# %%
# 2. 
# método ver_inventario(self):
# el método crea un diccionario con los nombres, precio y cantidad de los productos 
def ver_inventario(self):
    inventario = {}
    for producto in self.inventario:
            id_producto = producto["id"],
            nombre = producto["Nombre"],
            precio = ["Precio"],
            cantidad = ["Cantidad"]
            inventario[id_producto] = {
            "Nombre": nombre,
            "Precio": precio,
            "Cantidad": cantidad,
        }
# guardar primero en una lista, y después con ellos crear diccionario        
    return inventario
    
#id_producto_1 = inventario("camisa", 20, 40)
#id_producto_2 = inventario("pantalón", 30, 30)

# %%
#3.
# método buscar_producto(self, nombre):
#busca en el inventario por nombre; si está, imprime detalles

def buscar_producto(self, nombre):
    detalles = [] 
    for producto in self.inventario:
        if producto["nombre"] == nombre:
            detalles.append({
            "Nombre": nombre,
            "Precio": precio,
            "Cantidad": cantidad,
        })
    
    print(detalles)
    return

# %%
#4.
# actualizar_stock(self, nombre, cantidad):
# actualizar el stock, recibir el nombre del producto y la cantidad, y agregar o quitar cantidad 
# si no está, mensaje de alerta

def actualizar_stock(self, nombre=None, cantidad=None):
    if nombre in self.inventario:
        producto = self.inventario[nombre]
 
        if nombre is not None:
                producto[0] = nombre
        
        if cantidad is not None:
            nombre[1] = cantidad
            
        print(f"Cantidad del producto {nombre} actualizada")
        return self.inventario
    
    else:
        print(f"El producto {nombre} no aparece en el inventario. Para agregarlo utilice agregar_producto()")

# %%
#5
#eliminar_producto(self, nombre):
# bucle for para recorrer el inventario, busca el producto por nombre, 
# lo elimina si ya existe y si no está, mensaje indicándolo


def eliminar_producto(self, nombre):
    for producto in self.inventario:
    
        if producto["nombre"] not in self.inventario:
                print(f"el producto {nombre} no figura en el inventario.")
        else:
                self.inventario.remove[producto]
        return

# %%
#6
# calcular_valor_inventario(self):
# sumar los precios de todos los ejemplares de todos los productos

def calcular_valor_inventario(self):
    total_valor_stock = 0.0
    
    for producto in self.inventario:
        precio = producto["precio"] 
        cantidad = producto["cantidad"]
        
        # para implementar
        # habría que retirar si alguno es precio 0
        # if  producto[2] > 0:
        
        valor_stock_producto = precio * cantidad
        total_valor_stock += valor_stock_producto
    return total_valor_stock

# %%
#7
# método realizar_compra(self):
# permite al cliente realizar una compra seleccionando productos del inventario 
#debe interactuar con el cliente para seleccionar productos
#input para preguntar al cliente
#bucle while para permitir múltiples compras
#registra los productos seleccionados en un carrito 
#actualiza el inventario

def realizar_compra(self):
    
    carrito_compra = []     
    realizar_compra = input("¿desea realizar una compra? Responda sí o no")   
    # habría que ponerle más  código defensivo además del lower, sí con y sin tilde, etc...

    while realizar_compra.lower() == "sí":
        
        # mostrar inventario 
        print("inventario:")
        for producto in self.inventario:
            print(f"ID: {producto['id']}, Nombre: {producto['nombre']}, Precio: {producto['precio']}")
        

        producto_seleccionado = input("Indique el nombre del producto deseado")
        if producto_seleccionado in self.inventario:
            print(f"Información del producto seleccionado: {producto_seleccionado['nombre']}, Precio: {producto_seleccionado['precio']}, Cantidad disponible: {producto_seleccionado['cantidad']}")
            
            # seleccionado el objeto, preguntamos por la cantidad
            
            cantidad_producto = int(input(f"Indique cantidad de {producto_seleccionado} que desea"))

            if cantidad_producto <= producto_seleccionado["cantidad"]:
                carrito_compra.append({
                    "id_producto": producto_seleccionado["id"],
                    "nombre": producto_seleccionado["nombre"],
                    "cantidad": cantidad_producto,
                    "precio_total": producto_seleccionado["precio"] * cantidad_producto
                })
                    # obtiene precio total de la compra 
                    
                # actualizar inventario    
            producto_seleccionado["cantidad"] -= cantidad_producto
            print("Agregada su compra al carrito")
        
        realizar_compra = input("¿desea realizar una/otra compra? Responda sí o no")   
    
    # si no, va a pasar a carrito
    if carrito_compra:
        print("Compra realizada")
        for item in carrito_compra:
            print(f"Producto: {item['nombre']}, Cantidad: {item['cantidad']}, Precio Total: {item['precio_total']}")
        
    else:
        print("El carrito está vacío")

# %%
#id_producto_1 = inventario("camisa", 20, 40)
#id_producto_2 = inventario("pantalón", 30, 30)
